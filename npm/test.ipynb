# %%
from bs4 import BeautifulSoup
from selenium import webdriver 
from selenium.webdriver.chrome.options import Options
import re 
import urllib
from urllib.request import urlopen
import json

#create a webdriver object and set options for headless browsing
options = Options()
options.headless = True
browser = webdriver.Chrome('./chromedriver',options=options)

#uses webdriver object to execute javascript code and get dynamically loaded webcontent
def get_js_soup(url,browser):
    browser.get(url)
    res_html = browser.execute_script('return document.body.innerHTML')
    soup = BeautifulSoup(res_html,'html.parser') #beautiful soup object to be used for parsing html content
    return soup

def scrape_page(dir_url,browser):
    l = []
    #execute js on webpage to load listings on webpage and get ready to parse the loaded HTML 
    soup = get_js_soup(dir_url,browser)
    try:
        pv4 =  soup.find('div',class_='pv4')
        for a in pv4.find_all('a'):
            try:
                lib = a.contents[0] #get url
                l.append(lib)
            except:
                pass
    except:
        try:
            listp10 = get_js_soup(dir_url,browser).find('ul',class_='list p10')
            for a in listp10.find_all('a'):
                try:
                    lib = a.contents[0] #get url
                    l.append(lib)
                except:
                    pass
        except:
            pass
    return l

def fetch(lib):
    dir_url = "https://www.npmjs.com/package/"+str(lib) #base url
    return scrape_page(dir_url,browser)       

def main(input):
    listTopics = []
    for i in input:
        results = fetch(i)
        for j in results:
            if j not in listTopics:
                listTopics.append(j)
    with open('../../topic_lib_dic.json', 'r') as file:
        topic_lib_dic = json.loads(file.read())
    file.close()
    ret = {}
    for i in listTopics:
        if i in topic_lib_dic.keys():
            for j in topic_lib_dic[i]:
                if j not in ret.keys():
                    ret[j] = 1
                else:
                    ret[j] += 1
    return sorted(ret.items(), key=lambda kv: kv[1])[::-1]
    
    
if __name__ == '__main__':
    result = main(["react-bootstrap-typeahead","react-bootstrap-table","react-autosuggest","reactstrap","react-plotly.js"])
    print("#1:")
    print(result[0][0])
    print("#2:")
    print(result[1][0])
    print("#3:")
    print(result[2][0])
    print("result:")
    print(result)
# Out:
# #1:
# react-autosuggest
# #2:
# react-autowhatever
# #3:
# reactstrap
# result:
# [('react-autosuggest', 15), ('react-autowhatever', 14), ('reactstrap', 4), ('react-component', 4), ('react', 4), ('autosuggest-highlight', 4), ('antd', 3), ('downshift', 3), ('highcharts', 2), ('vega-lib', 2), ('@blueprintjs/core', 2), ('rebass', 2), ('react-logo', 2), ('autoresponsive-core', 2), ('react-sparklines', 2), ('react-kawaii', 2), ('react-annotation', 2), ('@coreui/react', 2), ('react-styleguidist', 2), ('react-taco-table', 2), ('react-motion', 2), ('react-values', 2), ('rc-time-picker', 2), ('component', 2), ('bootstrap', 2), ('select2', 2), ('labella', 1), ('@vx/pattern', 1), ('jointjs', 1), ('echarts', 1), ('d3-axis', 1), ('d3-shape', 1), ('d3-scale', 1), ('bizcharts', 1), ('d3', 1), ('sql.js', 1), ('@nx-js/observer-util', 1), ('ospath', 1), ('eslint-config-netflix-dea', 1), ('cp-file', 1), ('redux-storage', 1), ('tlds', 1), ('cpy', 1), ('d3-collection', 1), ('reflux-core', 1), ('electron-json-storage', 1), ('gray-matter', 1), ('electron-store', 1), ('istanbul-lib-coverage', 1), ('@wordpress/data', 1), ('@wordpress/core-data', 1), ('electron-config', 1), ('chart.js', 1), ('conf', 1), ('cpy-cli', 1), ('model', 1), ('reactive', 1), ('casual', 1), ('pretty-bytes', 1), ('mongoose', 1), ('country-data', 1), ('immutable', 1), ('react-native-progress', 1), ('react-native-collapsible', 1), ('@smooth-ui/core-sc', 1), ('react-x-ray', 1), ('rc-menu', 1), ('react-object-inspector', 1), ('imagesloaded', 1), ('react-native-icons', 1), ('storybook-host', 1), ('react-native-animatable', 1), ('rc-dialog', 1), ('popmotion', 1), ('react-native-htmlview', 1), ('react-icheck', 1), ('velocity-animate', 1), ('elemental', 1), ('jquery.flowchart', 1), ('jquery-ui-bundle', 1), ('featherlight', 1), ('prompts', 1), ('component-classes', 1), ('@compositor/x0', 1), ('@ephox/alloy', 1), ('cypress-testing-library', 1), ('rmc-dialog', 1), ('react-native-lightbox', 1), ('dom-testing-library', 1), ('relax-velocity-animate', 1), ('react-select', 1), ('autosize', 1), ('glow', 1), ('@atlaskit/css-reset', 1), ('react-native-vector-icons', 1), ('@atlaskit/tooltip', 1), ('@atlaskit/modal-dialog', 1), ('@atlaskit/icon', 1), ('react-testing-library', 1), ('aframe', 1), ('system-components', 1), ('react-shallow-testutils', 1), ('styled-normalize', 1), ('react-powerplug', 1), ('react-instantsearch', 1), ('@skatejs/val', 1), ('draft-js-buttons', 1), ('postcss-modules', 1), ('bit-javascript', 1), ('jss', 1), ('preact', 1), ('relax-fragments', 1), ('recompose', 1), ('@wordpress/components', 1), ('babel-plugin-react-transform', 1), ('gulp-vulcanize', 1), ('auto-bind', 1), ('react-side-effect', 1), ('re-resizable', 1), ('google-map-react', 1), ('react-native-snap-carousel', 1), ('react-radio-group', 1), ('react-numeric-input', 1), ('reapop-theme-wybo', 1), ('reapop', 1), ('compartment', 1), ('react-recaptcha', 1), ('timeago-react', 1), ('react-lite', 1), ('react-day-picker-themeable', 1), ('react-tagsinput', 1), ('react-radio-buttons', 1), ('react-async-component', 1), ('rsg-alt', 1), ('react-native-button', 1), ('react-swipeable-views', 1), ('react-native-segmented-control-tab', 1), ('react-universal-interface', 1), ('react-loader', 1), ('react-simple-dropdown', 1), ('react-slider', 1), ('react-google-analytics', 1), ('react-floater', 1), ('react-flip-move', 1), ('nano-css', 1), ('domain-browser', 1), ('svgr', 1), ('inferno-component', 1), ('react-waypoint', 1), ('component-metadata-loader', 1), ('react-ladda', 1), ('react-notification-system', 1), ('lazysizes', 1), ('react-inlinesvg', 1), ('react-frame-component', 1), ('react-fontawesome', 1), ('react-body-classname', 1), ('react-adsense', 1), ('rc-tween-one', 1), ('@lingui/react', 1), ('react-popper', 1), ('@reactions/component', 1), ('react-tether', 1), ('react-nouislider', 1), ('react-measure', 1), ('react-avatar', 1), ('react-component-renderless', 1), ('react-component-identity', 1), ('react-mount', 1), ('ionicons', 1), ('component-file-picker', 1), ('@alifd/next', 1), ('react-sortable-hoc', 1), ('popper. ...
